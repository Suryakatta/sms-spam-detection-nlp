# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("mail_data.csv")

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.value_counts("Category")
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df.loc[df['Category']=='spam','Category',]=0

# %%
df.loc[df['Category']=='ham','Category',]=1

# %%
df.head()
# Out:
#   Category                                            Message
# 0        1  Go until jurong point, crazy.. Available only ...
# 1        1                      Ok lar... Joking wif u oni...
# 2        0  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        1  U dun say so early hor... U c already then say...
# 4        1  Nah I don't think he goes to usf, he lives aro...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df.Message,df.Category,test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
v=CountVectorizer()

# %%
X_train_cv=v.fit_transform(X_train.values)

# %%
X_train_cv
# Out:
# <4457x7680 sparse matrix of type '<class 'numpy.int64'>'
# 	with 59204 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_train_cv.shape
# Out:
# (4457, 7680)

# %%
v.get_feature_names_out().shape
# Out:
# (7680,)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.pipeline import Pipeline
clf=Pipeline([('vectorizer',CountVectorizer()),
             ('nb',MultinomialNB())])

# %%
Y_train.shape
# Out:
# (4457,)

# %%
# If labels are numeric (0/1 or class IDs)
Y_train = Y_train.astype(int)

# If labels are strings (like "spam"/"ham")
Y_train = Y_train.astype(str)

# %%
clf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred=clf.predict(X_test)

# %%
Y_test = Y_test.astype(str)
y_pred = y_pred.astype(str)

# %%
from sklearn.metrics import classification_report

# %%
classification_report(Y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.97      0.92      0.94       149\n           1       0.99      1.00      0.99       966\n\n    accuracy                           0.99      1115\n   macro avg       0.98      0.96      0.97      1115\nweighted avg       0.99      0.99      0.99      1115\n'

# %%
from sklearn.metrics import accuracy_score

# %%
pred_on_train_data=clf.predict(X_train)

# %%
acc_train=accuracy_score(Y_train,pred_on_train_data)

# %%
print(acc_train)
# Out:
# 0.9937177473636976

# %%
pred_on_test_data=clf.predict(X_test)

# %%
acc_test=accuracy_score(Y_test,pred_on_test_data)

# %%
print(acc_test)
# Out:
# 0.9856502242152466
